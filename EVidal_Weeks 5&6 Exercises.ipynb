# %% [markdown]
# Data From Weeks 5 & 6 Datasets was used(BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Response)

# %% [markdown]
# Import all the needed libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("C:/Users/pro_v/Desktop/BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx")

# %%
data.head()
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# 2               48                            US
# 3               57                           usa
# 4               42                           USA
#
# ...

# %% [markdown]
# Chapter 7.
# Filter out missing data

# %%
for c in data.columns:
    miss = data[c].isnull().sum()
    if miss>0:
        print("{} has {} missing value(s)".format(c,miss))
    else:
        print("{} has NO missing value!".format(c))
# Out:
# Timestamp has NO missing value!
# Are you going actually going trick or treating yourself? has NO missing value!
# Your gender: has 9 missing value(s)
# How old are you? has 33 missing value(s)
# Which country do you live in? has 21 missing value(s)
# Which state, province, county do you live in? has 79 missing value(s)
#  [100 Grand Bar] has 78 missing value(s)
#  [Anonymous brown globs that come in black and orange wrappers] has 26 missing value(s)
#  [Any full-sized candy bar] has 17 missing value(s)
#  [Black Jacks] has 203 missing value(s)
#  [Bonkers (the candy)] has 221 missing value(s)
#  [Bonkers (the board game)] has 232 missing value(s)
#  [Bottle Caps] has 79 missing value(s)
#  [Box'o'Raisins] has 29 missing value(s)
#  [Broken glow stick] has 33 missing value(s)
#  [Butterfinger] has 23 missing value(s)
#  [Cadbury Creme Eggs] has 21 missing value(s)
#  [Candy Corn] has 17 missing value(s)
# ...

# %%
data1 = data.dropna()

# %%
data
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %%
data1
# Out:
# Empty DataFrame
# ...

# %%
dat2 = data.dropna(how='all')
dat2
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %% [markdown]
# Fill in missing data

# %%
gender = data[["Your gender:"]]

# %%
gender1 = gender.dropna()

# %%
gender1
# Out:
#      Your gender:
# 0            Male
# 1            Male
# 2          Female
# 3            Male
# 4            Male
# ...           ...
# 1254       Female
# 1255         Male
# 1256         Male
# 1257         Male
# 1258       Female
#
# [1250 rows x 1 columns]

# %% [markdown]
# Fill in missing data

# %% [markdown]
# Fill in missing data.
# Replace values

# %%
age = data[["How old are you?"]]

# %%
age1 = age.fillna(age.mean())

# %%
age1
# Out:
#      How old are you?
# 0                  22
# 1                  45
# 2                  48
# 3                  57
# 4                  42
# ...               ...
# 1254               52
# 1255               33
# 1256              NaN
# 1257               48
# 1258               44
#
# [1259 rows x 1 columns]

# %%
age.replace(np.nan,50)
# Out:
#      How old are you?
# 0                  22
# 1                  45
# 2                  48
# 3                  57
# 4                  42
# ...               ...
# 1254               52
# 1255               33
# 1256               50
# 1257               48
# 1258               44
#
# [1259 rows x 1 columns]

# %% [markdown]
# Remove duplicates

# %%
age.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1254     True
# 1255     True
# 1256     True
# 1257     True
# 1258     True
# Length: 1259, dtype: bool

# %%
age.drop_duplicates()
# Out:
#                        How old are you?
# 0                                    22
# 1                                    45
# 2                                    48
# 3                                    57
# 4                                    42
# ...                                 ...
# 1192                            ancient
# 1193                                142
# 1194                                  7
# 1197  Old enough to not Trick or Treat.
# 1245                        49 11/12ths
#
# [99 rows x 1 columns]

# %% [markdown]
# Chapter 8
# Create hierarchical index

# %%
data
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %% [markdown]
# Chapter 8 Combine and Merge Datasets (you will have to either create a new dataset from your existing data or create a relationship between the data I have provided)

# %%
df = pd.read_excel("C:/Users/pro_v/Desktop/CANDY-HIERARCHY-2015-SURVEY-Responses.xlsx")
df.head()
# Out:
#                 Timestamp How old are you?  \
# 0 2015-10-23 08:46:20.451               35
# 1 2015-10-23 08:46:51.583               41
# 2 2015-10-23 08:47:34.285               33
# 3 2015-10-23 08:47:58.964               31
# 4 2015-10-23 08:48:11.719               30
#
#   Are you going actually going trick or treating yourself?  [Butterfinger]  \
# 0                                                 No                   JOY
# 1                                                 No                   JOY
# 2                                                 No               DESPAIR
# 3                                                 No                   JOY
# 4                                                 No                   NaN
#
#    [100 Grand Bar]  \
# 0              NaN
# 1              JOY
# 2          DESPAIR
# 3              JOY
# 4              JOY
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# ...

# %%
df
# Out:
#                    Timestamp How old are you?  \
# 0    2015-10-23 08:46:20.451               35
# 1    2015-10-23 08:46:51.583               41
# 2    2015-10-23 08:47:34.285               33
# 3    2015-10-23 08:47:58.964               31
# 4    2015-10-23 08:48:11.719               30
# ...                      ...              ...
# 5625 2015-10-31 05:23:40.526               50
# 5626 2015-10-31 05:29:26.937               43
# 5627 2015-10-31 06:13:29.083               35
# 5628 2015-10-31 06:26:52.566               38
# 5629 2015-10-31 06:41:31.904               44
#
#      Are you going actually going trick or treating yourself?  [Butterfinger]  \
# 0                                                    No                   JOY
# 1                                                    No                   JOY
# 2                                                    No               DESPAIR
# 3                                                    No                   JOY
# ...

# %%
dfmerge = pd.merge(data,df)
dfmerge
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# Pivot the data

# %%
stacked = df.stack()

# %%
stacked
# Out:
# 0     Timestamp                                                                                                            2015-10-23 08:46:20.451000
#       How old are you?                                                                                                                             35
#       Are you going actually going trick or treating yourself?                                                                                     No
#        [Butterfinger]                                                                                                                             JOY
#        [Anonymous brown globs that come in black and orange wrappers]                                                                         DESPAIR
#                                                                                                                                       ...
# ...

# %% [markdown]
# Chapter 10 Grouping with Functions

# %%
group_functions = df[["How old are you?"]]
group_functions
# Out:
#      How old are you?
# 0                  35
# 1                  41
# 2                  33
# 3                  31
# 4                  30
# ...               ...
# 5625               50
# 5626               43
# 5627               35
# 5628               38
# 5629               44
#
# [5630 rows x 1 columns]

# %%
fun_group = df.groupby('How old are you?').mean()
fun_group
# Out:
#                   Fill in the blank: "Taylor Swift is a force for ___________"  \
# How old are you?
# 0                                                               NaN
# 0.62                                                            NaN
# 5                                                               NaN
# 6                                                               NaN
# 7                                                               NaN
# ...                                                             ...
# too old                                                         NaN
# too old for this                                                NaN
# very                                                            NaN
# x                                                               NaN
# ７１＋                                                             NaN
#
#                   Please estimate the degrees of separation you have from the following folks [Bruce Lee]  \
# ...

# %% [markdown]
# Cross Tabs

# %%
pd.crosstab(data["Are you going actually going trick or treating yourself?"],data["Your gender:"], margins=True)
# Out:
# Your gender:                                        Female  \
# Are you going actually going trick or treating ...
# No                                                     365
# Yes                                                     45
# All                                                    410
#
# Your gender:                                        I'd rather not say  Male  \
# Are you going actually going trick or treating ...
# No                                                                  25   707
# Yes                                                                  3    88
# All                                                                 28   795
#
# Your gender:                                        Other   All
# Are you going actually going trick or treating ...
# No                                                     16  1113
# Yes                                                     1   137
# All                                                    17  1250

# %% [markdown]
# Chapter 11 Generate date range

# %%
data = data.set_index(['Timestamp'])
print(data.loc['2016-10-28':'2016-10-30'])
# Out:
#                         Are you going actually going trick or treating yourself?  \
# Timestamp
# 2016-10-28 04:15:30.366                                                 No
# 2016-10-28 05:35:13.854                                                 No
# 2016-10-28 07:00:27.176                                                 No
# 2016-10-28 08:10:58.506                                                 No
# 2016-10-28 08:54:54.924                                                 No
# 2016-10-28 09:01:00.049                                                 No
# 2016-10-28 09:03:52.617                                                 No
# 2016-10-28 09:07:58.826                                                 No
# 2016-10-28 09:10:29.100                                                 No
# 2016-10-28 09:10:38.669                                                 No
# 2016-10-28 09:51:59.394                                                 No
# ...

# %%
Timestamp = df['Timestamp']
# Out:
# 0      2015-10-23 08:46:20.451
# 1      2015-10-23 08:46:51.583
# 2      2015-10-23 08:47:34.285
# 3      2015-10-23 08:47:58.964
# 4      2015-10-23 08:48:11.719
#                  ...
# 5625   2015-10-31 05:23:40.526
# 5626   2015-10-31 05:29:26.937
# 5627   2015-10-31 06:13:29.083
# 5628   2015-10-31 06:26:52.566
# 5629   2015-10-31 06:41:31.904
# Name: Timestamp, Length: 5630, dtype: datetime64[ns]

# %%
index = pd.date_range('2016-10-24','2016-10-25')
index
# Out:
# DatetimeIndex(['2016-10-24', '2016-10-25'], dtype='datetime64[ns]', freq='D')

# %%
str(Timestamp)
# Out:
# '0      2015-10-23 08:46:20.451\n1      2015-10-23 08:46:51.583\n2      2015-10-23 08:47:34.285\n3      2015-10-23 08:47:58.964\n4      2015-10-23 08:48:11.719\n                 ...          \n5625   2015-10-31 05:23:40.526\n5626   2015-10-31 05:29:26.937\n5627   2015-10-31 06:13:29.083\n5628   2015-10-31 06:26:52.566\n5629   2015-10-31 06:41:31.904\nName: Timestamp, Length: 5630, dtype: datetime64[ns]'
