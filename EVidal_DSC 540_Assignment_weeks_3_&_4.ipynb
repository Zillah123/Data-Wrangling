# %% [markdown]
# Activity 5: Generating Statistics from a CSV File

# %% [markdown]
# Load the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read in the Boston housing data set (given as a .csv file) from the local directory

# %%
boston_housing_data = pd.read_csv("C:/Users/pro_v/Desktop/Boston_housing.csv")
boston_housing_data.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'PRICE'],
#       dtype='object')

# %%
boston_housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
boston_housing_data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647422   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Check the first 10 records

# %%
boston_housing_data.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# ...

# %% [markdown]
# Total Number of Records

# %%
boston_housing_data.shape
# Out:
# (506, 14)

# %% [markdown]
# 4. Create a smaller DataFrame with columns that do not include CHAS, NOX, B, and LSTAT.

# %%
smaller_data = boston_housing_data.drop(["CHAS", "NOX", "B", "LSTAT"], axis=1)
smaller_data
# Out:
#         CRIM    ZN  INDUS     RM   AGE     DIS  RAD  TAX  PTRATIO  PRICE
# 0    0.00632  18.0   2.31  6.575  65.2  4.0900    1  296     15.3   24.0
# 1    0.02731   0.0   7.07  6.421  78.9  4.9671    2  242     17.8   21.6
# 2    0.02729   0.0   7.07  7.185  61.1  4.9671    2  242     17.8   34.7
# 3    0.03237   0.0   2.18  6.998  45.8  6.0622    3  222     18.7   33.4
# 4    0.06905   0.0   2.18  7.147  54.2  6.0622    3  222     18.7   36.2
# ..       ...   ...    ...    ...   ...     ...  ...  ...      ...    ...
# 501  0.06263   0.0  11.93  6.593  69.1  2.4786    1  273     21.0   22.4
# 502  0.04527   0.0  11.93  6.120  76.7  2.2875    1  273     21.0   20.6
# 503  0.06076   0.0  11.93  6.976  91.0  2.1675    1  273     21.0   23.9
# 504  0.10959   0.0  11.93  6.794  89.3  2.3889    1  273     21.0   22.0
# 505  0.04741   0.0  11.93  6.030  80.8  2.5050    1  273     21.0   11.9
#
# [506 rows x 10 columns]

# %% [markdown]
# 5. Check the last seven records of the new DataFrame you just created.

# %%
smaller_data.tail(7)
# Out:
#         CRIM   ZN  INDUS     RM   AGE     DIS  RAD  TAX  PTRATIO  PRICE
# 499  0.17783  0.0   9.69  5.569  73.5  2.3999    6  391     19.2   17.5
# 500  0.22438  0.0   9.69  6.027  79.7  2.4982    6  391     19.2   16.8
# 501  0.06263  0.0  11.93  6.593  69.1  2.4786    1  273     21.0   22.4
# 502  0.04527  0.0  11.93  6.120  76.7  2.2875    1  273     21.0   20.6
# 503  0.06076  0.0  11.93  6.976  91.0  2.1675    1  273     21.0   23.9
# 504  0.10959  0.0  11.93  6.794  89.3  2.3889    1  273     21.0   22.0
# 505  0.04741  0.0  11.93  6.030  80.8  2.5050    1  273     21.0   11.9

# %% [markdown]
# 6. Plot the histograms of all the variables (columns) in the new DataFrame.

# %%
for a in smaller_data.columns:    
    plt.title("Plot of "+a,fontsize=20)
    plt.hist(smaller_data[a],bins=20)
    plt.show()

# %% [markdown]
# 7. Plot them all at once using a for loop. Try to add a unique title to a plot.

# %%
for a in smaller_data.columns:  #iterate for each column
    plt.title("Plot of "+a,fontsize=20)
    plt.hist(smaller_data[a],bins=20)
    plt.show()

# %% [markdown]
# 8. Create a scatter plot of crime rate versus price.

# %%
plt.scatter(smaller_data['PRICE'],smaller_data['CRIM'])
plt.title("Scatter Plot of Crime Rate versus Price", fontsize=14)
plt.ylabel("Crime Rate")
plt.xlabel("Price")
plt.show()

# %% [markdown]
# Alternatively You can do this

# %%
plt.scatter(smaller_data['CRIM'],smaller_data['PRICE'])
plt.title("Scatter Plot of Crime Rate versus Price", fontsize=14)
plt.xlabel("Crime Rate")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# 9. Plot using log10(crime) versus price.

# %%
plt.scatter(np.log10(smaller_data['CRIM']),smaller_data['PRICE'],c='green')
plt.title("Crime rate (Log10) vs. Price plot", fontsize=18)
plt.xlabel("Log of Crime rate",fontsize=12)
plt.ylabel("Price",fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Alternatively

# %%
plt.scatter(np.log10(smaller_data['PRICE']),smaller_data['CRIM'],c='green')
plt.title("Crime rate (Log10) vs. Price plot", fontsize=18)
plt.ylabel("Log of Crime rate",fontsize=12)
plt.xlabel("Price",fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# 10. Calculate some useful statistics, such as mean rooms per dwelling, median age, mean distances to five Boston employment centers, and the percentage of houses with a low price (< $20,000).

# %% [markdown]
# a. Mean of rooms per dwelling

# %%
smaller_data["RM"].mean()
# Out:
# 6.284634387351788

# %%
smaller_data["AGE"].median()
# Out:
# 77.5

# %%
smaller_data["DIS"].mean()
# Out:
# 3.795042687747034

# %%
low_priced_houses = smaller_data['PRICE']<20
print(low_priced_houses)
percentage = low_priced_houses.mean()*100
print("\nPercentage of low priced houses (<20,000) is:", percentage)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505     True
# Name: PRICE, Length: 506, dtype: bool
#
# Percentage of low priced houses (<20,000) is: 41.50197628458498

# %% [markdown]
# End of Activity 5

# %% [markdown]
# Load the Necesaary Libraries(Already loaded)(PAndas, Numpy and MAtplotlib are loaded from previous activity)

# %%
2. Read the Adult income dataset which I have saved on my system.

# %%
adult_income_dataset = pd.read_csv("C:/Users/pro_v/Desktop/adult_income_data.csv")
adult_income_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2   77516           32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4   13              32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    Male           32560 non-null  object
#  9   2174            32560 non-null  int64
#  10  0               32560 non-null  int64
#  11  40              32560 non-null  int64
#  12   United-States  32560 non-null  object
#  13   <=50K          32560 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
adult_income_dataset.head(10)
# Out:
#    39          State-gov   77516      Bachelors  13           Never-married  \
# 0  50   Self-emp-not-inc   83311      Bachelors  13      Married-civ-spouse
# 1  38            Private  215646        HS-grad   9                Divorced
# 2  53            Private  234721           11th   7      Married-civ-spouse
# 3  28            Private  338409      Bachelors  13      Married-civ-spouse
# 4  37            Private  284582        Masters  14      Married-civ-spouse
# 5  49            Private  160187            9th   5   Married-spouse-absent
# 6  52   Self-emp-not-inc  209642        HS-grad   9      Married-civ-spouse
# 7  31            Private   45781        Masters  14           Never-married
# 8  42            Private  159449      Bachelors  13      Married-civ-spouse
# 9  37            Private  280464   Some-college  10      Married-civ-spouse
#
#          Adm-clerical   Not-in-family     Male   2174  0  40   United-States  \
# ...

# %%
adult_income_dataset.tail(10)
# Out:
#        39      State-gov   77516      Bachelors  13        Never-married  \
# 32550  32        Private   34066           10th   6   Married-civ-spouse
# 32551  43        Private   84661      Assoc-voc  11   Married-civ-spouse
# 32552  32        Private  116138        Masters  14        Never-married
# 32553  53        Private  321865        Masters  14   Married-civ-spouse
# 32554  22        Private  310152   Some-college  10        Never-married
# 32555  27        Private  257302     Assoc-acdm  12   Married-civ-spouse
# 32556  40        Private  154374        HS-grad   9   Married-civ-spouse
# 32557  58        Private  151910        HS-grad   9              Widowed
# 32558  22        Private  201490        HS-grad   9        Never-married
# 32559  52   Self-emp-inc  287927        HS-grad   9   Married-civ-spouse
#
#              Adm-clerical   Not-in-family     Male   2174  0  40  \
# 32550   Handlers-cleaners         Husband     Male      0  0  40
# ...

# %% [markdown]
# 3. Create a script that will read a text file line by line.

# %%
names = []
with open('C:/Users/pro_v/Desktop/adult_income_names.txt','r') as d:
    for line in d:
        d.readline()
        var=line.split(":")[0]
        names.append(var)

# %%
names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %% [markdown]
# 4. Add a name of Income for the response variable to the dataset.

# %%
names.append('Income')
adult_income_dataset = pd.read_csv("C:/Users/pro_v/Desktop/adult_income_data.csv", names=names)
adult_income_dataset.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship      sex  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# 5. Find the missing values

# %%
adult_income_dataset.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %% [markdown]
# 6. Create a DataFrame with only age, education, and occupation by using subsetting.

# %%
adult_income_dataset_subset = adult_income_dataset[['age','education','occupation']]
adult_income_dataset_subset.head()
# Out:
#    age   education          occupation
# 0   39   Bachelors        Adm-clerical
# 1   50   Bachelors     Exec-managerial
# 2   38     HS-grad   Handlers-cleaners
# 3   53        11th   Handlers-cleaners
# 4   28   Bachelors      Prof-specialty

# %% [markdown]
# 7. Plot a histogram of age with a bin size of 20.

# %%
adult_income_dataset_subset['age'].hist(bins=20)

# %%
adult_income_dataset_subset.boxplot(column='age',by='education',figsize=(15,6))
plt.xticks(fontsize=15)
plt.xlabel("Race",fontsize=20)
plt.show()

# %% [markdown]
# 8. Create a function to strip the whitespace characters.

# %%
def strip_whitespace(s):
    return s.strip()

# %% [markdown]
# 9. Use the apply method to apply this function to all the columns with string values, create a new column, copy the values from this new column to the old column, and drop the new column.

# %%
# Education column
adult_income_dataset_subset['education_stripped']=adult_income_dataset['education'].apply(strip_whitespace)
adult_income_dataset_subset['education']=adult_income_dataset_subset['education_stripped']
adult_income_dataset_subset.drop(labels=['education_stripped'],axis=1,inplace=True)

# Occupation column
adult_income_dataset_subset['occupation_stripped']=adult_income_dataset['occupation'].apply(strip_whitespace)
adult_income_dataset_subset['occupation']=adult_income_dataset_subset['occupation_stripped']
adult_income_dataset.drop(labels=['occupation_stripped'],axis=1,inplace=True)
# Out:
# C:\Users\pro_v\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\pro_v\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\pro_v\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# 10. Find the number of people who are aged between 30 and 50.

# %%
df_filtered=adult_income_dataset_subset[(adult_income_dataset_subset['age']>=30) & (adult_income_dataset_subset['age']<=50)]

# %%
df_filtered
# Out:
#        age     education         occupation occupation_stripped
# 0       39     Bachelors       Adm-clerical        Adm-clerical
# 1       50     Bachelors    Exec-managerial     Exec-managerial
# 2       38       HS-grad  Handlers-cleaners   Handlers-cleaners
# 5       37       Masters    Exec-managerial     Exec-managerial
# 6       49           9th      Other-service       Other-service
# ...    ...           ...                ...                 ...
# 32550   43  Some-college       Craft-repair        Craft-repair
# 32551   32          10th  Handlers-cleaners   Handlers-cleaners
# 32552   43     Assoc-voc              Sales               Sales
# 32553   32       Masters       Tech-support        Tech-support
# 32557   40       HS-grad  Machine-op-inspct   Machine-op-inspct
#
# [16390 rows x 4 columns]

# %% [markdown]
# 11. Group the records based on age and education to find how the mean age is distributed.

# %%
adult_income_dataset_subset.groupby(['education']).mean()
# Out:
#                     age
# education
# 10th          37.429796
# 11th          32.355745
# 12th          32.000000
# 1st-4th       46.142857
# 5th-6th       42.885886
# 7th-8th       48.445820
# 9th           41.060311
# Assoc-acdm    37.381443
# Assoc-voc     38.553546
# Bachelors     38.904949
# Doctorate     47.702179
# HS-grad       38.974479
# Masters       44.049913
# Preschool     42.764706
# Prof-school   44.746528
# Some-college  35.756275

# %% [markdown]
# 12. Group by occupation and show the summary statistics of age. Find which profession has the oldest workers on average and which profession has its largest share of the workforce above the 75th percentile.

# %%
adult_income_dataset_subset.groupby('occupation').describe()['age']
# Out:
#                     count       mean        std   min   25%   50%   75%   max
# occupation
# ?                  1843.0  40.882800  20.336350  17.0  21.0  35.0  61.0  90.0
# Adm-clerical       3770.0  36.964456  13.362998  17.0  26.0  35.0  46.0  90.0
# Armed-Forces          9.0  30.222222   8.089774  23.0  24.0  29.0  34.0  46.0
# Craft-repair       4099.0  39.031471  11.606436  17.0  30.0  38.0  47.0  90.0
# Exec-managerial    4066.0  42.169208  11.974548  17.0  33.0  41.0  50.0  90.0
# Farming-fishing     994.0  41.211268  15.070283  17.0  29.0  39.0  52.0  90.0
# Handlers-cleaners  1370.0  32.165693  12.372635  17.0  23.0  29.0  39.0  90.0
# Machine-op-inspct  2002.0  37.715285  12.068266  17.0  28.0  36.0  46.0  90.0
# Other-service      3295.0  34.949621  14.521508  17.0  22.0  32.0  45.0  90.0
# Priv-house-serv     149.0  41.724832  18.633688  17.0  24.0  40.0  57.0  81.0
# Prof-specialty     4140.0  40.517633  12.016676  17.0  31.0  40.0  48.0  90.0
# ...

# %%
# Exec-Managerial had the oldest worker on average (42.169 years)
# ? the occupation has the largest share of workforce above 75TH percentile followed by Priv-house-serv

# %% [markdown]
# 13. Use subset and groupby to find outliers.

# %%
occupation_stats= adult_income_dataset_subset.groupby('occupation').describe()['age']

# %% [markdown]
# 14. Plot the values on a bar chart.

# %%
plt.figure(figsize=(15,8))
plt.barh(y=occupation_stats.index,width=occupation_stats['count'])
plt.yticks(fontsize=13)
plt.show()

# %% [markdown]
# 15. Merge the data using common keys.

# %%
df_1 = adult_income_dataset[['age','workclass','occupation']].sample(5,random_state=101)

# %%
df_1.head()
# Out:
#        age workclass          occupation
# 22357   51   Private   Machine-op-inspct
# 26009   19   Private               Sales
# 20734   40   Private     Exec-managerial
# 17695   17   Private   Handlers-cleaners
# 27908   61   Private        Craft-repair

# %%
df_2 = adult_income_dataset[['education','sex','occupation']].sample(5,random_state=101)

# %%
df_2.head()
# Out:
#       education      sex          occupation
# 22357   HS-grad   Female   Machine-op-inspct
# 26009      11th     Male               Sales
# 20734   HS-grad     Male     Exec-managerial
# 17695      10th     Male   Handlers-cleaners
# 27908   7th-8th     Male        Craft-repair

# %%
df_merged = pd.merge(df_1,df_2,on='occupation',how='inner').drop_duplicates()

# %%
df_merged
# Out:
#    age workclass          occupation education      sex
# 0   51   Private   Machine-op-inspct   HS-grad   Female
# 1   19   Private               Sales      11th     Male
# 2   40   Private     Exec-managerial   HS-grad     Male
# 3   17   Private   Handlers-cleaners      10th     Male
# 4   61   Private        Craft-repair   7th-8th     Male

# %% [markdown]
# Create a series and practice basic arithmetic steps

# %% [markdown]
# a. Series 1 = 7.3, -2.5, 3.4, 1.5
#
# i. Index = ‘a’, ‘c’, ‘d’, ‘e’

# %%
data_1 = [7.3, -2.5, 3.4, 1.5]
index_1 = ['a', 'c', 'd', 'e']
series_1 = pd.Series(data_1, index=index_1)

# %%
series_1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
type(series_1)
# Out:
# pandas.core.series.Series

# %% [markdown]
# b. Series 2 = -2.1, 3.6, -1.5, 4, 3.1
#
# i. Index = ‘a’, ‘c’, ‘e’, ‘f’, ‘g’

# %%
data_2 = [-2.1, 3.6, -1.5, 4, 3.1]
index_2 = ['a', 'c', 'e','f','g']
series_2 = pd.Series(data_2, index=index_2)
series_2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
type(series_2)
# Out:
# pandas.core.series.Series

# %% [markdown]
# c. Add Series 1 and Series 2 together and print the results

# %%
series_1.add(series_2, fill_value=0)
# Out:
# a    5.2
# c    1.1
# d    3.4
# e    0.0
# f    4.0
# g    3.1
# dtype: float64

# %% [markdown]
# d. Subtract Series 1 from Series 2 and print the results

# %%
#series 1 minus series 2
series_1.subtract(series_2, fill_value=0)
# Out:
# a    9.4
# c   -6.1
# d    3.4
# e    3.0
# f   -4.0
# g   -3.1
# dtype: float64

# %%
#Alternatively series2 minus(-) series1 
series_2.subtract(series_1, fill_value=0)
# Out:
# a   -9.4
# c    6.1
# d   -3.4
# e   -3.0
# f    4.0
# g    3.1
# dtype: float64

# %% [markdown]
# 4. Data Wrangling with Python: Activity 7, page 207

# %%
# for this exercise we only need to import beautifulsoup as pandas is already imported
from bs4 import BeautifulSoup

# %% [markdown]
# 1. Open the page in a separate Chrome/Firefox tab and use something like an Inspect Element tool to view the source HTML and understand its structure. Performed.

# %% [markdown]
# 2. Read the page using bs4

# %%
fd = open("C:/Users/pro_v/Desktop/List of countries by GDP (nominal) - Wikipedia.htm", "r",encoding = "utf-8")
soup = BeautifulSoup(fd)
fd.close()
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0064)https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal) -->
# <html class="client-js gr__en_wikipedia_org ve-not-available" dir="ltr" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    List of countries by GDP (nominal) - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
#Alternatively you can open with the code below
with open("C:/Users/pro_v/Desktop/List of countries by GDP (nominal) - Wikipedia.htm", "r", encoding="utf-8")as tc:
    soup_1 = BeautifulSoup(tc)
print(soup_1.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0064)https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal) -->
# <html class="client-js gr__en_wikipedia_org ve-not-available" dir="ltr" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    List of countries by GDP (nominal) - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %% [markdown]
# 3. Find the table structure you will need to deal with (how many tables there are?)

# %%
all_tables = soup.find_all("table")
print("Total number of tables are {} ".format(len(all_tables)))
# Out:
# Total number of tables are 9

# %% [markdown]
# 4. Find the right table using bs4

# %%
data_table = soup.find("table", {"class": '"wikitable"|}'})
print(type(data_table))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# 5. Separate the source names and their corresponding data

# %%
sources = data_table.tbody.findAll('tr', recursive=False)[0]
sources_list = [td for td in sources.findAll('td')]
print(len(sources_list))
# Out:
# 3

# %%
data = data_table.tbody.findAll('tr', recursive=False)[1].findAll('td', recursive=False)

# %%
data_tables = []
for td in data:
    data_tables.append(td.findAll('table'))
len(data_tables)
# Out:
# 3

# %% [markdown]
# 6. Get the source names from the list of sources you have created

# %%
source_names = [source.findAll('a')[0].getText() for source in sources_list]
print(source_names)
# Out:
# ['International Monetary Fund', 'World Bank', 'United Nations']

# %% [markdown]
# 7. Separate the header and data from the data that you separated before for the first source only, and then create a DataFrame using that

# %%
header1 = [th.getText().strip() for th in data_tables[0][0].findAll('thead')[0].findAll('th')]
header1
# Out:
# ['Rank', 'Country', 'GDP(US$MM)']

# %%
rows1 = data_tables[0][0].findAll('tbody')[0].findAll('tr')[1:]
data_rows1 = [[td.get_text().strip() for td in tr.findAll('td')] for tr in rows1]
df1 = pd.DataFrame(data_rows1, columns=header1)
df1.head()
# Out:
#   Rank         Country  GDP(US$MM)
# 0    1   United States  19,390,600
# 1    2      China[n 1]  12,014,610
# 2    3           Japan   4,872,135
# 3    4         Germany   3,684,816
# 4    5  United Kingdom   2,624,529

# %% [markdown]
# 8. Repeat the last task for the other two data sources

# %%
header2 = [th.getText().strip() for th in data_tables[1][0].findAll('thead')[0].findAll('th')]
header2
# Out:
# ['Rank', 'Country', 'GDP(US$MM)']

# %%
rows2 = data_tables[1][0].findAll('tbody')[0].findAll('tr')[1:]
def find_right_text(i, td):
    if i == 0:
        return td.getText().strip()
    elif i == 1:
        return td.getText().strip()
    else:
        index = td.text.find("♠")
        return td.text[index+1:].strip()

data_rows2 = [[find_right_text(i, td) for i, td in enumerate(tr.findAll('td'))] for tr in rows2]
df2 = pd.DataFrame(data_rows2, columns=header2)
df2.head()
# Out:
#   Rank             Country  GDP(US$MM)
# 0    1       United States  19,390,604
# 1       European Union[23]  17,277,698
# 2    2          China[n 4]  12,237,700
# 3    3               Japan   4,872,137
# 4    4             Germany   3,677,439

# %%
# Third one
header3 = [th.getText().strip() for th in data_tables[2][0].findAll('thead')[0].findAll('th')]
header3
# Out:
# ['Rank', 'Country', 'GDP(US$MM)']

# %%
rows3 = data_tables[2][0].findAll('tbody')[0].findAll('tr')[1:]
data_rows3 = [[find_right_text(i, td) for i, td in enumerate(tr.findAll('td'))] for tr in rows2]
df3 = pd.DataFrame(data_rows3, columns=header3)
df3.head()
# Out:
#   Rank             Country  GDP(US$MM)
# 0    1       United States  19,390,604
# 1       European Union[23]  17,277,698
# 2    2          China[n 4]  12,237,700
# 3    3               Japan   4,872,137
# 4    4             Germany   3,677,439

# %% [markdown]
# 5. Data Wrangling with Python: Activity 8, page 233

# %% [markdown]
# 1. Read the visit_data.csv file.

# %%
df_8 = pd.read_csv("C:/Users/pro_v/Desktop/visit_data.csv")
df_8.head()
# Out:
#    id first_name last_name                       email gender  \
# 0   1      Sonny      Dahl            sdahl0@mysql.com   Male
# 1   2        NaN       NaN           dhoovart1@hud.gov    NaN
# 2   3        Gar     Armal      garmal2@technorati.com    NaN
# 3   4    Chiarra     Nulty       cnulty3@newyorker.com    NaN
# 4   5        NaN       NaN  sleaver4@elegantthemes.com    NaN
#
#         ip_address   visit
# 0    135.36.96.183  1225.0
# 1  237.165.194.143   919.0
# 2   166.43.137.224   271.0
# 3   139.98.137.108  1002.0
# 4    46.117.117.27  2434.0

# %%
df_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  704 non-null    object
#  2   last_name   704 non-null    object
#  3   email       1000 non-null   object
#  4   gender      495 non-null    object
#  5   ip_address  1000 non-null   object
#  6   visit       974 non-null    float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 54.8+ KB

# %%
df_8.describe()
# Out:
#                 id        visit
# count  1000.000000   974.000000
# mean    500.500000  1497.976386
# std     288.819436   838.959460
# min       1.000000     1.000000
# 25%     250.750000   794.500000
# 50%     500.500000  1477.000000
# 75%     750.250000  2224.250000
# max    1000.000000  2998.000000

# %% [markdown]
# 2. Check for duplicates.

# %%
print("First name is duplictaed - {}".format(any(df_8.first_name.duplicated())))
print("Last name is duplictaed - {}".format(any(df_8.last_name.duplicated())))
print("Email is duplictaed - {}".format(any(df_8.email.duplicated())))
# Out:
# First name is duplictaed - True
# Last name is duplictaed - True
# Email is duplictaed - False

# %% [markdown]
# 3. Check if any essential column contains NaN.

# %%
print("The column Email contains NaN - %r " % df_8.email.isnull().values.any())
print("The column IP Address contains NaN - %s " % df_8.ip_address.isnull().values.any())
print("The column Visit contains NaN - %s " % df_8.visit.isnull().values.any())
# Out:
# The column Email contains NaN - False
# The column IP Address contains NaN - False
# The column Visit contains NaN - True

# %% [markdown]
# 4. Get rid of the outliers.

# %%
size_prev = df_8.shape
df_8 = df_8[np.isfinite(df_8['visit'])]
size_after = df_8.shape

# %% [markdown]
# 5. Report the size difference.

# %%
print("The size of previous data was - {prev[0]} rows and the size of the new one is - {after[0]} rows".
      format(prev=size_prev, after=size_after))
# Out:
# The size of previous data was - 1000 rows and the size of the new one is - 974 rows

# %% [markdown]
# 6. Create a box plot to check for outliers.

# %%
plt.boxplot(df_8.visit, notch=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26aecd2d588>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26aecd3fdc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26aecd35f08>],
#  'medians': [<matplotlib.lines.Line2D at 0x26aecd42fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26aecd42d48>],
#  'means': []}

# %% [markdown]
# 7. Get rid of any outliers.

# %%
df1 = df_8[(df_8['visit'] <= 2900) & (df_8['visit'] >= 100)]
print("After getting rid of outliers the new size of the data is - {}".format(*df1.shape))
# Out:
# After getting rid of outliers the new size of the data is - 923

# %% [markdown]
# 6. Insert data into a SQL Lite database – create a table with the following data (Hint: Python for Data Analysis page 191):
#
# a. Name, Address, City, State, Zip, Phone Number
#
# b. Add at least 10 rows of data and submit your code with a query generating your results.

# %%
import sqlite3

# %%
query = """CREATE TABLE test
(a VARCHAR(30), b VARCHAR(30),
c VARCHAR(20), d VARCHAR(20),
e INTEGER, f INTEGER
);"""

# %%
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)

# %%
con.commit()

# %%
data = [('Sudheer', '1215 lake blv', 'Marion', 'Ohio', 43302, 8324566893),
       ('Michael', '206 Eisenhower way', 'Bellevue', 'Nebraska', 68005, 4124938373),
       ('vilius', '1206 Park way', 'Bedford', 'Texas', 96021, 8174359123),
       ('Matthew', '637 McArthur Blvd', 'Tallahassee', 'Florida', 32307, 8503849673),
       ('Emmanuel', '845 6th Avenue', 'Duncansville', 'Pennsylvania', 16635, 8146379524),
       ('Ravindra', '2600 summit ridge drive', 'Southlake', 'Texas', 76092, 8325789024),
       ('Daniel', '705 main street', 'Euless', 'Texas',76039, 8325735927),
       ('Bhargava', '500 Lee road', 'Phenix City', 'Alabama',36870, 3345869305),
       ('Evan','600 Davis road', 'Miami', 'Florida', 33122, 3054627485),
       ('Hedyeh', '6049 Cobra lane', 'Clarksville', 'Tennessee', 37042, 9325066485),
       ('Tolulope', '2600 Brewster Drive', 'Clarksville', 'Tennessee', 37042, 9327598401),
       ('Solomon', '2800 Brewster drive', 'Clarksville', 'Tennessee', 37042, 9324589024)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?, ?, ?)"

# %%
con.executemany(stmt, data)

# %%
con.commit()

# %%
cursor = con.execute('select * from test')

# %%
rows = cursor.fetchall()

# %%
rows
# Out:
# [('Sudheer', '1215 lake blv', 'Marion', 'Ohio', 43302, 8324566893),
#  ('Michael', '206 Eisenhower way', 'Bellevue', 'Nebraska', 68005, 4124938373),
#  ('vilius', '1206 Park way', 'Bedford', 'Texas', 96021, 8174359123),
#  ('Matthew', '637 McArthur Blvd', 'Tallahassee', 'Florida', 32307, 8503849673),
#  ('Emmanuel',
#   '845 6th Avenue',
#   'Duncansville',
#   'Pennsylvania',
#   16635,
#   8146379524),
#  ('Ravindra',
#   '2600 summit ridge drive',
#   'Southlake',
#   'Texas',
#   76092,
#   8325789024),
#  ('Daniel', '705 main street', 'Euless', 'Texas', 76039, 8325735927),
#  ('Bhargava', '500 Lee road', 'Phenix City', 'Alabama', 36870, 3345869305),
#  ('Evan', '600 Davis road', 'Miami', 'Florida', 33122, 3054627485),
#  ('Hedyeh', '6049 Cobra lane', 'Clarksville', 'Tennessee', 37042, 9325066485),
#  ('Tolulope',
#   '2600 Brewster Drive',
#   'Clarksville',
#   'Tennessee',
#   37042,
#   9327598401),
#  ('Solomon',
#   '2800 Brewster drive',
#   'Clarksville',
# ...

# %%
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None),
#  ('e', None, None, None, None, None, None),
#  ('f', None, None, None, None, None, None))

# %%
df = pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
df
# Out:
#            a                        b             c             d      e  \
# 0    Sudheer            1215 lake blv        Marion          Ohio  43302
# 1    Michael       206 Eisenhower way      Bellevue      Nebraska  68005
# 2     vilius            1206 Park way       Bedford         Texas  96021
# 3    Matthew        637 McArthur Blvd   Tallahassee       Florida  32307
# 4   Emmanuel           845 6th Avenue  Duncansville  Pennsylvania  16635
# 5   Ravindra  2600 summit ridge drive     Southlake         Texas  76092
# 6     Daniel          705 main street        Euless         Texas  76039
# 7   Bhargava             500 Lee road   Phenix City       Alabama  36870
# 8       Evan           600 Davis road         Miami       Florida  33122
# 9     Hedyeh          6049 Cobra lane   Clarksville     Tennessee  37042
# 10  Tolulope      2600 Brewster Drive   Clarksville     Tennessee  37042
# 11   Solomon      2800 Brewster drive   Clarksville     Tennessee  37042
#
#              f
# ...

# %%
df.columns = ['Name','Address','City','State', 'Zip-Code','Phone Number']

# %%
df
# Out:
#         Name                  Address          City         State  Zip-Code  \
# 0    Sudheer            1215 lake blv        Marion          Ohio     43302
# 1    Michael       206 Eisenhower way      Bellevue      Nebraska     68005
# 2     vilius            1206 Park way       Bedford         Texas     96021
# 3    Matthew        637 McArthur Blvd   Tallahassee       Florida     32307
# 4   Emmanuel           845 6th Avenue  Duncansville  Pennsylvania     16635
# 5   Ravindra  2600 summit ridge drive     Southlake         Texas     76092
# 6     Daniel          705 main street        Euless         Texas     76039
# 7   Bhargava             500 Lee road   Phenix City       Alabama     36870
# 8       Evan           600 Davis road         Miami       Florida     33122
# 9     Hedyeh          6049 Cobra lane   Clarksville     Tennessee     37042
# 10  Tolulope      2600 Brewster Drive   Clarksville     Tennessee     37042
# ...
